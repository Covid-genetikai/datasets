# %%
import json
import pandas as pd
pd.set_option('display.max_columns', 30)

# %%
metadata = pd.read_csv("/usbf/data/covid/gisaid/metadata_2021-03-01_09-16.tsv", delimiter='\t')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
metadata.head()
# Out:
#                       strain virus   gisaid_epi_isl genbank_accession  \
# 0  Afghanistan/IMB07956/2020  ncov  EPI_ISL_1034760                 ?
# 1  Afghanistan/IMB07958/2020  ncov  EPI_ISL_1000998                 ?
# 2  Afghanistan/IMB07960/2020  ncov  EPI_ISL_1000999                 ?
# 3  Afghanistan/IMB07962/2020  ncov  EPI_ISL_1001000                 ?
# 4  Afghanistan/IMB07964/2020  ncov  EPI_ISL_1001001                 ?
#
#          date region      country     division location region_exposure  \
# 0  2020-06-06   Asia  Afghanistan  Afghanistan      NaN            Asia
# 1  2020-06-13   Asia  Afghanistan  Afghanistan      NaN            Asia
# 2  2020-06-07   Asia  Afghanistan  Afghanistan      NaN            Asia
# 3  2020-06-02   Asia  Afghanistan  Afghanistan      NaN            Asia
# 4  2020-05-30   Asia  Afghanistan  Afghanistan      NaN            Asia
#
#   country_exposure division_exposure segment  length   host age sex  \
# ...

# %%
metadata.shape
# Out:
# (634539, 28)

# %%
metadata.division.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Boufarik', ..., 'Radviliskio Apskritis',
#        'China', 'Guangxi'], dtype=object)

# %%
metadata.host.unique()
# Out:
# array(['Human', 'Environment', 'Felis catus', 'Rhinolophus shameli',
#        'Rhinolophus affinis', 'Rhinolophus malayanus',
#        'Canis lupus familiaris', 'Gorilla Gorilla Gorilla',
#        'Panthera leo', 'Mink', 'Chlorocebus sabaeus', 'Mus musculus',
#        'Mus musculus (BALB/c mice)', 'Manis javanica',
#        'Manis pentadactyla', 'Panthera tigris jacksoni'], dtype=object)

# %%
metadata[metadata["host"]=="Human"].shape
# Out:
# (633328, 28)

# %%
metadata[metadata["genbank_accession"]=="?"].shape
# Out:
# (577448, 28)

# %%
metadata.genbank_accession.unique()
# Out:
# array(['?', 'MT641655.1', 'MT641660.1', ..., 'MW626397.1', 'MW626398.1',
#        'MW477798.1'], dtype=object)

# %%
metadata[metadata["genbank_accession"]=="MN985325.1"]
# Out:
#               strain virus  gisaid_epi_isl genbank_accession        date  \
# 593033  USA/WA1/2020  ncov  EPI_ISL_404895        MN985325.1  2020-01-19
#
#                region country    division          location region_exposure  \
# 593033  North America     USA  Washington  Snohomish County            Asia
#
#        country_exposure division_exposure segment  length   host age   sex  \
# 593033            China             Hubei  genome   29882  Human   ?  Male
#
#        Nextstrain_clade pangolin_lineage GISAID_clade  \
# 593033              19B              A.1            S
#
#                            originating_lab  \
# 593033  Providence Regional Medical Center
#
#                                            submitting_lab      authors  \
# 593033  Division of Viral Diseases, Centers for Diseas...  Queen et al
#
#                            url  \
# 593033  https://www.gisaid.org
#
#                                                     title  \
# ...

# %%
metadata[metadata["country"]=="Lithuania"]
# Out:
#                                           strain virus  gisaid_epi_isl  \
# 372480             Lithuania/AL-LUHS-Eilnr1/2020  ncov  EPI_ISL_603082
# 372481             Lithuania/AL-LUHS-Eilnr2/2020  ncov  EPI_ISL_603083
# 372482                 Lithuania/C20-05-R10/2020  ncov  EPI_ISL_560391
# 372483                 Lithuania/C20-05-R11/2020  ncov  EPI_ISL_560392
# 372484                 Lithuania/C20-05-R13/2020  ncov  EPI_ISL_560393
# ...                                          ...   ...             ...
# 634061   mink/Lithuania/MR-LUHS-Eilnr147957/2020  ncov  EPI_ISL_851057
# 634062  mink/Lithuania/MR-LUHS-Eilnr1490411/2020  ncov  EPI_ISL_851058
# 634063  mink/Lithuania/MR-LUHS-Eilnr1490415/2020  ncov  EPI_ISL_851059
# 634064  mink/Lithuania/MR-LUHS-Eilnr1490420/2020  ncov  EPI_ISL_851060
# 634065   mink/Lithuania/MR-LUHS-Eilnr173423/2020  ncov  EPI_ISL_851061
#
#        genbank_accession        date  region    country  \
# 372480                 ?  2020-04-02  Europe  Lithuania
# ...

# %%
mjs = json.load(open("/usbf/data/covid/gisaid/ncov_global.json", "r"))
mdf = pd.read_json("/usbf/data/covid/gisaid/ncov_global.json")

# %%
mdf
# Out:
#                                                                  meta  \
# build_url                          https://github.com/nextstrain/ncov
# colorings           [{'key': 'clade_membership', 'title': 'Clade',...
# description         Compiled Nextstrain SARS-CoV-2 resources are a...
# display_defaults    {'branch_label': 'clade', 'color_by': 'clade_m...
# filters             [recency, clade_membership, region, country, d...
# genome_annotations  {'E': {'end': 26472, 'seqid': 'defaults/refere...
# geo_resolutions     [{'demes': {'Accra': {'latitude': 5.591875, 'l...
# maintainers         [{'name': 'the Nextstrain team', 'url': 'https...
# panels                              [tree, map, entropy, frequencies]
# title               Genomic epidemiology of novel coronavirus - Gl...
# updated                                                    2021-02-26
# branch_attrs                                                      NaN
# ...

# %%
metadata.keys()
# Out:
# dict_keys(['meta', 'tree', 'version'])

# %%
metadata["meta"]["genome_annotations"]
# Out:
# {'E': {'end': 26472,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 26245,
#   'strand': '+',
#   'type': 'CDS'},
#  'M': {'end': 27191,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 26523,
#   'strand': '+',
#   'type': 'CDS'},
#  'N': {'end': 29533,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 28274,
#   'strand': '+',
#   'type': 'CDS'},
#  'ORF1a': {'end': 13468,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 266,
#   'strand': '+',
#   'type': 'CDS'},
#  'ORF1b': {'end': 21555,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 13468,
#   'strand': '+',
#   'type': 'CDS'},
#  'ORF3a': {'end': 26220,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 25393,
#   'strand': '+',
#   'type': 'CDS'},
#  'ORF6': {'end': 27387,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 27202,
#   'strand': '+',
#   'type': 'CDS'},
#  'ORF7a': {'end': 27759,
#   'seqid': 'defaults/reference_seq.gb',
#   'start': 27394,
#   'strand': '+',
# ...

# %%
len(metadata["tree"]["children"].keys())

# %%
mdf
# Out:
#                                                                  meta  \
# build_url                          https://github.com/nextstrain/ncov
# colorings           [{'key': 'clade_membership', 'title': 'Clade',...
# description         Compiled Nextstrain SARS-CoV-2 resources are a...
# display_defaults    {'branch_label': 'clade', 'color_by': 'clade_m...
# filters             [recency, clade_membership, region, country, d...
# genome_annotations  {'E': {'end': 26472, 'seqid': 'defaults/refere...
# geo_resolutions     [{'demes': {'Accra': {'latitude': 5.591875, 'l...
# maintainers         [{'name': 'the Nextstrain team', 'url': 'https...
# panels                              [tree, map, entropy, frequencies]
# title               Genomic epidemiology of novel coronavirus - Gl...
# updated                                                    2021-02-26
# branch_attrs                                                      NaN
# ...
